# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashikala803/NLP-EXPT5/blob/main/NLP_EXPT_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('punkt_tab')
para = """Bluetooth is a short-range, wireless technology standard for exchanging data between fixed and mobile devices over, typically within 10 meters (33 feet). It uses low-power, 2.4 GHz ISM radio waves to connect peripherals like headphones, keyboards, and speakers to devices such as phones and computers. """
sentence= nltk.sent_tokenize(para)
sentence
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# ['Bluetooth is a short-range, wireless technology standard for exchanging data between fixed and mobile devices over, typically within 10 meters (33 feet).',
#  'It uses low-power, 2.4 GHz ISM radio waves to connect peripherals like headphones, keyboards, and speakers to devices such as phones and computers.']

# %%
from nltk.tokenize import word_tokenize

words = word_tokenize(para)
print(words)
# Out:
# ['Bluetooth', 'is', 'a', 'short-range', ',', 'wireless', 'technology', 'standard', 'for', 'exchanging', 'data', 'between', 'fixed', 'and', 'mobile', 'devices', 'over', ',', 'typically', 'within', '10', 'meters', '(', '33', 'feet', ')', '.', 'It', 'uses', 'low-power', ',', '2.4', 'GHz', 'ISM', 'radio', 'waves', 'to', 'connect', 'peripherals', 'like', 'headphones', ',', 'keyboards', ',', 'and', 'speakers', 'to', 'devices', 'such', 'as', 'phones', 'and', 'computers', '.']

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(w) for w in words]

print(lemmatized_words)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# ['Bluetooth', 'is', 'a', 'short-range', ',', 'wireless', 'technology', 'standard', 'for', 'exchanging', 'data', 'between', 'fixed', 'and', 'mobile', 'device', 'over', ',', 'typically', 'within', '10', 'meter', '(', '33', 'foot', ')', '.', 'It', 'us', 'low-power', ',', '2.4', 'GHz', 'ISM', 'radio', 'wave', 'to', 'connect', 'peripheral', 'like', 'headphone', ',', 'keyboard', ',', 'and', 'speaker', 'to', 'device', 'such', 'a', 'phone', 'and', 'computer', '.']

# %%
sentence
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
stemmer = PorterStemmer()

# %%
for i in range (len (sentence)):
    words=nltk.word_tokenize(sentence[i])
    words=[stemmer.stem(word)for word in words]
    sentence[i]=''.join(words)

# %%
sentence
# Out:
# ['bluetoothisashort-rang,wirelesstechnologstandardforexchangdatabetweenfixandmobildevicover,typicwithin10meter(33feet).',
#  'ituselow-pow,2.4ghzismradiowavetoconnectperipherlikeheadphon,keyboard,andspeakertodevicsuchasphoneandcomput.']

# %%
from nltk.stem import WordNetLemmatizer
para1="""Bluetooth is a short-range, wireless technology standard for exchanging data between fixed and mobile devices over, typically within 10 meters (33 feet). It uses low-power, 2.4 GHz ISM radio waves to connect peripherals like headphones, keyboards, and speakers to devices such as phones and computers. """
sentence1=nltk.sent_tokenize(para1)
sentence
# Out:
# ['bluetoothisashort-rang,wirelesstechnologstandardforexchangdatabetweenfixandmobildevicover,typicwithin10meter(33feet).',
#  'ituselow-pow,2.4ghzismradiowavetoconnectperipherlikeheadphon,keyboard,andspeakertodevicsuchasphoneandcomput.']

# %%
lemmatizer=WordNetLemmatizer()
for i in range (len(sentence)):
    pass # Placeholder for future code, as the loop body was empty

# %%
nltk.download('averaged_perceptron_tagger_eng')
word=nltk.word_tokenize(para)
tag_word=nltk.pos_tag(word)
tag_word
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [('Bluetooth', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('short-range', 'NN'),
#  (',', ','),
#  ('wireless', 'NN'),
#  ('technology', 'NN'),
#  ('standard', 'NN'),
#  ('for', 'IN'),
#  ('exchanging', 'VBG'),
#  ('data', 'NNS'),
#  ('between', 'IN'),
#  ('fixed', 'VBN'),
#  ('and', 'CC'),
#  ('mobile', 'JJ'),
#  ('devices', 'NNS'),
#  ('over', 'IN'),
#  (',', ','),
#  ('typically', 'RB'),
#  ('within', 'IN'),
#  ('10', 'CD'),
#  ('meters', 'NNS'),
#  ('(', '('),
#  ('33', 'CD'),
#  ('feet', 'NNS'),
#  (')', ')'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('uses', 'VBZ'),
#  ('low-power', 'JJR'),
#  (',', ','),
#  ('2.4', 'CD'),
#  ('GHz', 'NNP'),
#  ('ISM', 'NNP'),
#  ('radio', 'NN'),
#  ('waves', 'NNS'),
#  ('to', 'TO'),
#  ('connect', 'VB'),
#  ('peripherals', 'NNS'),
#  ('like', 'IN'),
#  ('headphones', 'NNS'),
#  (',', ','),
#  ('keyboards', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('speakers', 'NNS'),
#  ('to', 'TO'),
#  ('devices', 'NNS'),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('phones', 'NNS'),
#  ('and', 'CC'),
#  ('computers', 'NNS'),
#  ('.', '.')]

# %%
# !pip install svgling
import nltk
para = """Bluetooth is a short-range, wireless technology standard for exchanging data between fixed and mobile devices over, typically within 10 meters (33 feet). It uses low-power, 2.4 GHz ISM radio waves to connect peripherals like headphones, keyboards, and speakers to devices such as phones and computers. """
nltk.download('punkt_tab') # Added this line to download the missing resource
nltk.download('averaged_perceptron_tagger_eng')
word=nltk.word_tokenize(para)
tag_word=nltk.pos_tag(word)
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
named_ent=nltk.ne_chunk(tag_word)
named_ent
# Out:
# Collecting svgling
#   Downloading svgling-0.5.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting svgwrite (from svgling)
#   Downloading svgwrite-1.4.3-py3-none-any.whl.metadata (8.8 kB)
# Downloading svgling-0.5.0-py3-none-any.whl (31 kB)
# Downloading svgwrite-1.4.3-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: svgwrite, svgling
# Successfully installed svgling-0.5.0 svgwrite-1.4.3
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# Tree('S', [Tree('GPE', [('Bluetooth', 'NNP')]), ('is', 'VBZ'), ('a', 'DT'), ('short-range', 'NN'), (',', ','), ('wireless', 'NN'), ('technology', 'NN'), ('standard', 'NN'), ('for', 'IN'), ('exchanging', 'VBG'), ('data', 'NNS'), ('between', 'IN'), ('fixed', 'VBN'), ('and', 'CC'), ('mobile', 'JJ'), ('devices', 'NNS'), ('over', 'IN'), (',', ','), ('typically', 'RB'), ('within', 'IN'), ('10', 'CD'), ('meters', 'NNS'), ('(', '('), ('33', 'CD'), ('feet', 'NNS'), (')', ')'), ('.', '.'), ('It', 'PRP'), ('uses', 'VBZ'), ('low-power', 'JJR'), (',', ','), ('2.4', 'CD'), Tree('ORGANIZATION', [('GHz', 'NNP')]), ('ISM', 'NNP'), ('radio', 'NN'), ('waves', 'NNS'), ('to', 'TO'), ('connect', 'VB'), ('peripherals', 'NNS'), ('like', 'IN'), ('headphones', 'NNS'), (',', ','), ('keyboards', 'NNS'), (',', ','), ('and', 'CC'), ('speakers', 'NNS'), ('to', 'TO'), ('devices', 'NNS'), ('such', 'JJ'), ('as', 'IN'), ('phones', 'NNS'), ('and', 'CC'), ('computers', 'NNS'), ('.', '.')])

# %%
named_ent
# Out:
# Tree('S', [Tree('GPE', [('Bluetooth', 'NNP')]), ('is', 'VBZ'), ('a', 'DT'), ('short-range', 'NN'), (',', ','), ('wireless', 'NN'), ('technology', 'NN'), ('standard', 'NN'), ('for', 'IN'), ('exchanging', 'VBG'), ('data', 'NNS'), ('between', 'IN'), ('fixed', 'VBN'), ('and', 'CC'), ('mobile', 'JJ'), ('devices', 'NNS'), ('over', 'IN'), (',', ','), ('typically', 'RB'), ('within', 'IN'), ('10', 'CD'), ('meters', 'NNS'), ('(', '('), ('33', 'CD'), ('feet', 'NNS'), (')', ')'), ('.', '.'), ('It', 'PRP'), ('uses', 'VBZ'), ('low-power', 'JJR'), (',', ','), ('2.4', 'CD'), Tree('ORGANIZATION', [('GHz', 'NNP')]), ('ISM', 'NNP'), ('radio', 'NN'), ('waves', 'NNS'), ('to', 'TO'), ('connect', 'VB'), ('peripherals', 'NNS'), ('like', 'IN'), ('headphones', 'NNS'), (',', ','), ('keyboards', 'NNS'), (',', ','), ('and', 'CC'), ('speakers', 'NNS'), ('to', 'TO'), ('devices', 'NNS'), ('such', 'JJ'), ('as', 'IN'), ('phones', 'NNS'), ('and', 'CC'), ('computers', 'NNS'), ('.', '.')])

# %%
# title problems hw:stop word removal

# %%
# !pip install svgling
# Out:
# Requirement already satisfied: svgling in /usr/local/lib/python3.12/dist-packages (0.5.0)
# Requirement already satisfied: svgwrite in /usr/local/lib/python3.12/dist-packages (from svgling) (1.4.3)

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')

para = """Bluetooth is a short-range wireless technology standard that is used for exchanging data between fixed and mobile devices over short distances and building personal area networks (PANs). In the most widely used mode, transmission power is limited to 2.5 milliwatts, giving it a very short range of up to 10 metres (33 ft). It employs UHF radio waves in the ISM bands, from 2.402 GHz to 2.48 GHz.[3] It is mainly used as an alternative to wired connections to exchange files between nearby portable devices and connect cell phones and music players with wireless headphones, wireless speakers, HIFI systems, car audio and wireless transmission between TVs and soundbars.

Bluetooth is managed by the Bluetooth Special Interest Group (SIG), which has more than 35,000 member companies in the areas of telecommunication, computing, networking, and consumer electronics. The IEEE standardized Bluetooth as IEEE 802.15.1 but no longer maintains the standard. The Bluetooth SIG oversees the development of the specification, manages the qualification program, and protects the trademarks.[4] A manufacturer must meet Bluetooth SIG standards to market it as a Bluetooth device.[5] A network of patents applies to the technology, which is licensed to individual qualifying devices. As of 2021, 4.7 billion Bluetooth integrated circuit chips are shipped annually.[6] Bluetooth was first demonstrated in space in 2024, an early test envisioned to enhance IoT capabilities."""

sentence = nltk.sent_tokenize(para)
sentence
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# ['Bluetooth is a short-range wireless technology standard that is used for exchanging data between fixed and mobile devices over short distances and building personal area networks (PANs).',
#  'In the most widely used mode, transmission power is limited to 2.5 milliwatts, giving it a very short range of up to 10 metres (33 ft).',
#  'It employs UHF radio waves in the ISM bands, from 2.402 GHz to 2.48 GHz.',
#  '[3] It is mainly used as an alternative to wired connections to exchange files between nearby portable devices and connect cell phones and music players with wireless headphones, wireless speakers, HIFI systems, car audio and wireless transmission between TVs and soundbars.',
#  'Bluetooth is managed by the Bluetooth Special Interest Group (SIG), which has more than 35,000 member companies in the areas of telecommunication, computing, networking, and consumer electronics.',
#  'The IEEE standardized Bluetooth as IEEE 802.15.1 but no longer maintains the standard.',
#  'The Bluetooth SIG oversees the development of the specification, manages the qualification program, and protects the trademarks.',
#  '[4] A manufacturer must meet Bluetooth SIG standards to market it as a Bluetooth device.',
#  '[5] A network of patents applies to the technology, which is licensed to individual qualifying devices.',
#  'As of 2021, 4.7 billion Bluetooth integrated circuit chips are shipped annually.',
#  '[6] Bluetooth was first demonstrated in space in 2024, an early test envisioned to enhance IoT capabilities.']

# %%
sentence
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

stemmer = PorterStemmer()
for i in range(len(sentence)):
  words = nltk.word_tokenize(sentence[i])
  words = [stemmer.stem(word) for word in words]
  sentence[i] = ' '.join(words)

sentence
# Out:
# ['bluetooth is a short-rang wireless technolog standard that is use for exchang data between fix and mobil devic over short distanc and build person area network ( pan ) .',
#  'in the most wide use mode , transmiss power is limit to 2.5 milliwatt , give it a veri short rang of up to 10 metr ( 33 ft ) .',
#  'it employ uhf radio wave in the ism band , from 2.402 ghz to 2.48 ghz .',
#  '[ 3 ] it is mainli use as an altern to wire connect to exchang file between nearbi portabl devic and connect cell phone and music player with wireless headphon , wireless speaker , hifi system , car audio and wireless transmiss between tv and soundbar .',
#  'bluetooth is manag by the bluetooth special interest group ( sig ) , which ha more than 35,000 member compani in the area of telecommun , comput , network , and consum electron .',
#  'the ieee standard bluetooth as ieee 802.15.1 but no longer maintain the standard .',
#  'the bluetooth sig overse the develop of the specif , manag the qualif program , and protect the trademark .',
#  '[ 4 ] a manufactur must meet bluetooth sig standard to market it as a bluetooth devic .',
#  '[ 5 ] a network of patent appli to the technolog , which is licens to individu qualifi devic .',
#  'as of 2021 , 4.7 billion bluetooth integr circuit chip are ship annual .',
#  '[ 6 ] bluetooth wa first demonstr in space in 2024 , an earli test envis to enhanc iot capabl .']

# %%
from nltk.stem import WordNetLemmatizer

para1 = """Bluetooth is a short-range wireless technology standard that is used for exchanging data between fixed and mobile devices over short distances and building personal area networks (PANs). In the most widely used mode, transmission power is limited to 2.5 milliwatts, giving it a very short range of up to 10 metres (33 ft). It employs UHF radio waves in the ISM bands, from 2.402 GHz to 2.48 GHz.[3] It is mainly used as an alternative to wired connections to exchange files between nearby portable devices and connect cell phones and music players with wireless headphones, wireless speakers, HIFI systems, car audio and wireless transmission between TVs and soundbars.

Bluetooth is managed by the Bluetooth Special Interest Group (SIG), which has more than 35,000 member companies in the areas of telecommunication, computing, networking, and consumer electronics. The IEEE standardized Bluetooth as IEEE 802.15.1 but no longer maintains the standard. The Bluetooth SIG oversees the development of the specification, manages the qualification program, and protects the trademarks.[4] A manufacturer must meet Bluetooth SIG standards to market it as a Bluetooth device.[5] A network of patents applies to the technology, which is licensed to individual qualifying devices. As of 2021, 4.7 billion Bluetooth integrated circuit chips are shipped annually.[6] Bluetooth was first demonstrated in space in 2024, an early test envisioned to enhance IoT capabilities."""
sentence1 = nltk.sent_tokenize(para1)

sentence1
# Out:
# ['Bluetooth is a short-range wireless technology standard that is used for exchanging data between fixed and mobile devices over short distances and building personal area networks (PANs).',
#  'In the most widely used mode, transmission power is limited to 2.5 milliwatts, giving it a very short range of up to 10 metres (33 ft).',
#  'It employs UHF radio waves in the ISM bands, from 2.402 GHz to 2.48 GHz.',
#  '[3] It is mainly used as an alternative to wired connections to exchange files between nearby portable devices and connect cell phones and music players with wireless headphones, wireless speakers, HIFI systems, car audio and wireless transmission between TVs and soundbars.',
#  'Bluetooth is managed by the Bluetooth Special Interest Group (SIG), which has more than 35,000 member companies in the areas of telecommunication, computing, networking, and consumer electronics.',
#  'The IEEE standardized Bluetooth as IEEE 802.15.1 but no longer maintains the standard.',
#  'The Bluetooth SIG oversees the development of the specification, manages the qualification program, and protects the trademarks.',
#  '[4] A manufacturer must meet Bluetooth SIG standards to market it as a Bluetooth device.',
#  '[5] A network of patents applies to the technology, which is licensed to individual qualifying devices.',
#  'As of 2021, 4.7 billion Bluetooth integrated circuit chips are shipped annually.',
#  '[6] Bluetooth was first demonstrated in space in 2024, an early test envisioned to enhance IoT capabilities.']

# %%
lemmatizer=WordNetLemmatizer()

for i in range(len(sentence1)):
  words = nltk.word_tokenize(sentence1[i])
  newwords = [lemmatizer.lemmatize(word) for word in words]
  sentence1[i] = ' '.join(newwords)

sentence1

para2 = """Bluetooth is a short-range wireless technology standard that is used for exchanging data between fixed and mobile devices over short distances and building personal area networks (PANs). In the most widely used mode, transmission power is limited to 2.5 milliwatts, giving it a very short range of up to 10 metres (33 ft). It employs UHF radio waves in the ISM bands, from 2.402 GHz to 2.48 GHz.[3] It is mainly used as an alternative to wired connections to exchange files between nearby portable devices and connect cell phones and music players with wireless headphones, wireless speakers, HIFI systems, car audio and wireless transmission between TVs and soundbars.

Bluetooth is managed by the Bluetooth Special Interest Group (SIG), which has more than 35,000 member companies in the areas of telecommunication, computing, networking, and consumer electronics. The IEEE standardized Bluetooth as IEEE 802.15.1 but no longer maintains the standard. The Bluetooth SIG oversees the development of the specification, manages the qualification program, and protects the trademarks.[4] A manufacturer must meet Bluetooth SIG standards to market it as a Bluetooth device.[5] A network of patents applies to the technology, which is licensed to individual qualifying devices. As of 2021, 4.7 billion Bluetooth integrated circuit chips are shipped annually.[6] Bluetooth was first demonstrated in space in 2024, an early test envisioned to enhance IoT capabilities."""

sentences2 = nltk.sent_tokenize(para2)

for i in range(len(sentences2)):
  words = nltk.word_tokenize(sentences2[i])
  newwords = [word for word in words if word not in stopwords.words('english')]
  sentences2[i] = ' '.join(newwords)
sentences2
# Out:
# ['Bluetooth short-range wireless technology standard used exchanging data fixed mobile devices short distances building personal area networks ( PANs ) .',
#  'In widely used mode , transmission power limited 2.5 milliwatts , giving short range 10 metres ( 33 ft ) .',
#  'It employs UHF radio waves ISM bands , 2.402 GHz 2.48 GHz .',
#  '[ 3 ] It mainly used alternative wired connections exchange files nearby portable devices connect cell phones music players wireless headphones , wireless speakers , HIFI systems , car audio wireless transmission TVs soundbars .',
#  'Bluetooth managed Bluetooth Special Interest Group ( SIG ) , 35,000 member companies areas telecommunication , computing , networking , consumer electronics .',
#  'The IEEE standardized Bluetooth IEEE 802.15.1 longer maintains standard .',
#  'The Bluetooth SIG oversees development specification , manages qualification program , protects trademarks .',
#  '[ 4 ] A manufacturer must meet Bluetooth SIG standards market Bluetooth device .',
#  '[ 5 ] A network patents applies technology , licensed individual qualifying devices .',
#  'As 2021 , 4.7 billion Bluetooth integrated circuit chips shipped annually .',
#  '[ 6 ] Bluetooth first demonstrated space 2024 , early test envisioned enhance IoT capabilities .']

# %%
# !pip install svgling

para3 = """Bluetooth is a short-range wireless technology standard that is used for exchanging data between fixed and mobile devices over short distances and building personal area networks (PANs). In the most widely used mode, transmission power is limited to 2.5 milliwatts, giving it a very short range of up to 10 metres (33 ft). It employs UHF radio waves in the ISM bands, from 2.402 GHz to 2.48 GHz.[3] It is mainly used as an alternative to wired connections to exchange files between nearby portable devices and connect cell phones and music players with wireless headphones, wireless speakers, HIFI systems, car audio and wireless transmission between TVs and soundbars.

Bluetooth is managed by the Bluetooth Special Interest Group (SIG), which has more than 35,000 member companies in the areas of telecommunication, computing, networking, and consumer electronics. The IEEE standardized Bluetooth as IEEE 802.15.1 but no longer maintains the standard. The Bluetooth SIG oversees the development of the specification, manages the qualification program, and protects the trademarks.[4] A manufacturer must meet Bluetooth SIG standards to market it as a Bluetooth device.[5] A network of patents applies to the technology, which is licensed to individual qualifying devices. As of 2021, 4.7 billion Bluetooth integrated circuit chips are shipped annually.[6] Bluetooth was first demonstrated in space in 2024, an early test envisioned to enhance IoT capabilities."""

word = nltk.word_tokenize(para3)

tag_word = nltk.pos_tag(word)

tag_word

named_Ent = nltk.ne_chunk(tag_word)

named_Ent
# Out:
# Requirement already satisfied: svgling in /usr/local/lib/python3.12/dist-packages (0.5.0)
# Requirement already satisfied: svgwrite in /usr/local/lib/python3.12/dist-packages (from svgling) (1.4.3)
# Tree('S', [Tree('GPE', [('Bluetooth', 'NNP')]), ('is', 'VBZ'), ('a', 'DT'), ('short-range', 'JJ'), ('wireless', 'NN'), ('technology', 'NN'), ('standard', 'NN'), ('that', 'WDT'), ('is', 'VBZ'), ('used', 'VBN'), ('for', 'IN'), ('exchanging', 'VBG'), ('data', 'NNS'), ('between', 'IN'), ('fixed', 'VBN'), ('and', 'CC'), ('mobile', 'JJ'), ('devices', 'NNS'), ('over', 'IN'), ('short', 'JJ'), ('distances', 'NNS'), ('and', 'CC'), ('building', 'VBG'), ('personal', 'JJ'), ('area', 'NN'), ('networks', 'NNS'), ('(', '('), ('PANs', 'NNP'), (')', ')'), ('.', '.'), ('In', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('widely', 'RB'), ('used', 'VBN'), ('mode', 'NN'), (',', ','), ('transmission', 'NN'), ('power', 'NN'), ('is', 'VBZ'), ('limited', 'VBN'), ('to', 'TO'), ('2.5', 'CD'), ('milliwatts', 'NNS'), (',', ','), ('giving', 'VBG'), ('it', 'PRP'), ('a', 'DT'), ('very', 'RB'), ('short', 'JJ'), ('range', 'NN'), ('of', 'IN'), ('up', 'IN'), ('to', 'TO'), ('10', 'CD'), ('metres', 'NNS'), ('(', '('), ('33', 'CD'), ('ft', 'NN'), (')', ')'), ('.', '.'), ('It', 'PRP'), ('employs', 'VBZ'), Tree('ORGANIZATION', [('UHF', 'NNP')]), ('radio', 'NN'), ('waves', 'NNS'), ('in', 'IN'), ('the', 'DT'), Tree('ORGANIZATION', [('ISM', 'NNP')]), ('bands', 'NNS'), (',', ','), ('from', 'IN'), ('2.402', 'CD'), ('GHz', 'NNP'), ('to', 'TO'), ('2.48', 'CD'), ('GHz', 'NNP'), ('.', '.'), ('[', 'CC'), ('3', 'CD'), (']', 'NN'), ('It', 'PRP'), ('is', 'VBZ'), ('mainly', 'RB'), ('used', 'VBN'), ('as', 'IN'), ('an', 'DT'), ('alternative', 'NN'), ('to', 'TO'), ('wired', 'VB'), ('connections', 'NNS'), ('to', 'TO'), ('exchange', 'VB'), ('files', 'NNS'), ('between', 'IN'), ('nearby', 'JJ'), ('portable', 'JJ'), ('devices', 'NNS'), ('and', 'CC'), ('connect', 'NN'), ('cell', 'NN'), ('phones', 'NNS'), ('and', 'CC'), ('music', 'NN'), ('players', 'NNS'), ('with', 'IN'), ('wireless', 'JJ'), ('headphones', 'NNS'), (',', ','), ('wireless', 'NN'), ('speakers', 'NNS'), (',', ','), Tree('ORGANIZATION', [('HIFI', 'NNP')]), ('systems', 'NNS'), (',', ','), ('car', 'NN'), ('audio', 'NN'), ('and', 'CC'), ('wireless', 'JJ'), ('transmission', 'NN'), ('between', 'IN'), Tree('ORGANIZATION', [('TVs', 'NNP')]), ('and', 'CC'), ('soundbars', 'NNS'), ('.', '.'), Tree('PERSON', [('Bluetooth', 'NNP')]), ('is', 'VBZ'), ('managed', 'VBN'), ('by', 'IN'), ('the', 'DT'), Tree('ORGANIZATION', [('Bluetooth', 'NNP'), ('Special', 'NNP'), ('Interest', 'NNP'), ('Group', 'NNP')]), ('(', '('), Tree('ORGANIZATION', [('SIG', 'NNP')]), (')', ')'), (',', ','), ('which', 'WDT'), ('has', 'VBZ'), ('more', 'JJR'), ('than', 'IN'), ('35,000', 'CD'), ('member', 'NN'), ('companies', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('areas', 'NNS'), ('of', 'IN'), ('telecommunication', 'NN'), (',', ','), ('computing', 'VBG'), (',', ','), ('networking', 'NN'), (',', ','), ('and', 'CC'), ('consumer', 'NN'), ('electronics', 'NNS'), ('.', '.'), ('The', 'DT'), Tree('ORGANIZATION', [('IEEE', 'NNP')]), ('standardized', 'VBD'), Tree('PERSON', [('Bluetooth', 'NNP')]), ('as', 'IN'), Tree('ORGANIZATION', [('IEEE', 'NNP')]), ('802.15.1', 'CD'), ('but', 'CC'), ('no', 'RB'), ('longer', 'JJR'), ('maintains', 'VBZ'), ('the', 'DT'), ('standard', 'NN'), ('.', '.'), ('The', 'DT'), Tree('ORGANIZATION', [('Bluetooth', 'NNP')]), ('SIG', 'NNP'), ('oversees', 'VBZ'), ('the', 'DT'), ('development', 'NN'), ('of', 'IN'), ('the', 'DT'), ('specification', 'NN'), (',', ','), ('manages', 'VBZ'), ('the', 'DT'), ('qualification', 'NN'), ('program', 'NN'), (',', ','), ('and', 'CC'), ('protects', 'VBZ'), ('the', 'DT'), ('trademarks', 'NNS'), ('.', '.'), ('[', '$'), ('4', 'CD'), (']', 'CC'), ('A', 'DT'), ('manufacturer', 'NN'), ('must', 'MD'), ('meet', 'VB'), Tree('PERSON', [('Bluetooth', 'NNP'), ('SIG', 'NNP')]), ('standards', 'NNS'), ('to', 'TO'), ('market', 'NN'), ('it', 'PRP'), ('as', 'IN'), ('a', 'DT'), ('Bluetooth', 'NNP'), ('device', 'NN'), ('.', '.'), ('[', 'CC'), ('5', 'CD'), (']', 'NN'), ('A', 'NNP'), ('network', 'NN'), ('of', 'IN'), ('patents', 'NNS'), ('applies', 'NNS'), ('to',  ...
