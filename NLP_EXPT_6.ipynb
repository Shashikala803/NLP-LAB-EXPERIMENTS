# %% [markdown]
# <a href="https://colab.research.google.com/github/Dheerajnath/NLP-EXPT6/blob/main/NLP_EXPT_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 84.3 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
from nltk.stem import PorterStemmer

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")

# Sample text
text = "Apple is looking at buying a startup in Bengaluru for $1 billion."

# Process text
doc = nlp(text)

print("Original Text:")
print(text)
# Out:
# Original Text:
# Apple is looking at buying a startup in Bengaluru for $1 billion.

# %%
# 1. TOKENIZATION
print("Tokenization:")
tokens = [token.text for token in doc]
print(tokens)
# Out:
# Tokenization:
# ['Apple', 'is', 'looking', 'at', 'buying', 'a', 'startup', 'in', 'Bengaluru', 'for', '$', '1', 'billion', '.']

# %%
# 2. STEMMING (spaCy doesn't support stemming directly, so use NLTK)
ps = PorterStemmer()
stemmed_words = [ps.stem(token.text) for token in doc if token.is_alpha]
print("\nStemming:")
print(stemmed_words)
# Out:
# Stemming:
# ['appl', 'is', 'look', 'at', 'buy', 'a', 'startup', 'in', 'bengaluru', 'for', 'billion']

# %%
lemmas = [token.lemma_ for token in doc]
print("\nLemmatization:")
print(lemmas)
# Out:
# Lemmatization:
# ['Apple', 'be', 'look', 'at', 'buy', 'a', 'startup', 'in', 'Bengaluru', 'for', '$', '1', 'billion', '.']

# %%
print("\nPOS Tagging:")
for token in doc:
    print(token.text, "->", token.pos_)
# Out:
# POS Tagging:
# Apple -> PROPN
# is -> AUX
# looking -> VERB
# at -> ADP
# buying -> VERB
# a -> DET
# startup -> NOUN
# in -> ADP
# Bengaluru -> PROPN
# for -> ADP
# $ -> SYM
# 1 -> NUM
# billion -> NUM
# . -> PUNCT

# %%
# 5. NAMED ENTITY RECOGNITION (NER)
print("\nNamed Entity Recognition:")
for ent in doc.ents:
    print(ent.text, "->", ent.label_)
# Out:
# Named Entity Recognition:
# Apple -> ORG
# Bengaluru -> GPE
# $1 billion -> MONEY

# %%
# 6. STOP WORD REMOVAL
stopwords_removed = [token.text for token in doc if not token.is_stop and token.is_alpha]
print("\nStop Word Removal:")
print(stopwords_removed)
# Out:
# Stop Word Removal:
# ['Apple', 'looking', 'buying', 'startup', 'Bengaluru', 'billion']

# %%
import spacy

# Load ML-based spaCy model
nlp = spacy.load("en_core_web_sm")

# Input text
text = "The children are playing football in the park."

# Process text using trained ML model
doc = nlp(text)

print("Word\tPOS Tag\tLemma")
print("---------------------------")

# POS Tagging and Lemmatization
for token in doc:
    print(token.text, "\t", token.pos_, "\t", token.lemma_)
# Out:
# Word	POS Tag	Lemma
# ---------------------------
# The 	 DET 	 the
# children 	 NOUN 	 child
# are 	 AUX 	 be
# playing 	 VERB 	 play
# football 	 NOUN 	 football
# in 	 ADP 	 in
# the 	 DET 	 the
# park 	 NOUN 	 park
# . 	 PUNCT 	 .

# %%
# !pip install emoji
import re
import emoji

text = "Heeey!!! This is soooo cooool 😍😍 $$$"

print("Original Text:")
print(text)

# Lowercase
text = text.lower()

# Remove emojis
text = emoji.replace_emoji(text, replace='')

# Remove special characters
text = re.sub(r'[^a-z\s]', '', text)

# Reduce ALL repeated characters to ONE
text = re.sub(r'(.)\1+', r'\1', text)

# Restore valid 'oo' (optional but needed)
text = re.sub(r'\bcol\b', 'cool', text)

# Remove extra spaces
text = re.sub(r'\s+', ' ', text).strip()

print("\nCleaned Text:")
print(text)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 10.0 MB/s eta 0:00:00
# ...
# Original Text:
# Heeey!!! This is soooo cooool 😍😍 $$$
#
# Cleaned Text:
# hey this is so cool
